# %% [markdown]
# ### Import module

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#Import the necessary libraries first

import tensorflow as tf
import os
import keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# %matplotlib inline
from tensorflow.keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator,load_img, img_to_array
from tensorflow.keras.metrics import categorical_crossentropy
from keras.models import Sequential, Model
from keras.layers import Conv2D, MaxPooling2D,GlobalAveragePooling2D
from keras.layers import Activation, Dropout, BatchNormalization, Flatten, Dense, AvgPool2D,MaxPool2D
from keras.models import Sequential, Model
from keras import backend as K
import shutil
import glob
import re

# %%
data = '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /brain_tumor_dataset'
No_brain_tumor = '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no'
Yes_brain_tumor = '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /yes'

# %% [markdown]
# ### Creating a dataframe showing tumour class with corresponding filepath

# %%
dirlist=[No_brain_tumor, Yes_brain_tumor]
# ['brain_tumor_dataset/no/', 'brain_tumor_dataset/yes/']
classes=['No', 'Yes']
filepaths=[]
labels=[]
for i,j in zip(dirlist, classes):
# i
# ../input/brain-mri-images-for-brain-tumor-detection/no/
# ../input/brain-mri-images-for-brain-tumor-detection/yes/
# j
# No
# Yes

    filelist=os.listdir(i)
    print(filelist)
    print('\n')
# os.listdir --> returns a list containing the names of the entries in the directory given by path.
    for f in filelist:
        filepath=os.path.join (i,f)
# os.path.join('brain_tumor_dataset/no/','1 no.jpeg;)
# brain_tumor_dataset/no/1 no.jpeg
        filepaths.append(filepath)
# store the path into empty list called filepaths
        labels.append(j)
    print(filepaths)
    print('\n')
    print(labels)
    print('\n')
print ('filepaths: ', len(filepaths), '   labels: ', len(labels))
# Out:
# ['14 no.jpg', '31 no.jpg', '32 no.jpg', '10 no.jpg', '12 no.jpg', '17 no.jpg', '23 no.jpg', '20 no.jpg', '22 no.jpg', '1 no.jpeg', '28 no.jpg', '19 no.jpg', '18 no.jpg', '2 no.jpeg', '15 no.jpg', '29 no.jpg', '30 no.jpg', '27 no.jpg', '13 no.jpg', '26 no.jpg', '11 no.jpg', '34 no.jpg', '21 no.jpg', '24 no.jpg', '33 no.jpg', '25 no.jpg', '3 no.jpg', '50 no.jpg', 'No14.jpg', '39 no.jpg', 'N16.jpg', 'No11.jpg', '5 no.jpg', '6 no.jpg', '42 no.jpg', 'no 100.jpg', 'N19.JPG', 'No21.jpg', 'No18.jpg', '40 no.jpg', '38 no.jpg', '48 no.jpeg', '36 no.jpg', 'N2.JPG', 'No17.jpg', '4 no.jpg', 'N15.jpg', 'N11.jpg', 'no 6.jpg', 'no 4.jpg', 'No22.jpg', '44no.jpg', 'N20.JPG', 'no 8.jpg', '8 no.jpg', '35 no.jpg', 'No16.jpg', '41 no.jpg', 'no 92.jpg', 'N1.JPG', 'N3.jpg', 'N6.jpg', 'N5.jpg', 'no 89.jpg', 'no 7.jpeg', 'no 3.jpg', 'no 10.jpg', 'N21.jpg', 'N26.JPG', 'N17.jpg', 'no 1.jpg', 'no 90.jpg', 'No15.jpg', 'N22.JPG', '9 no.jpg', '7 no.jpg', 'no 9.png', '47 no.jpg', 'No13.jpg', 'No20.jpg', 'No19.jpg', '43 no.jpg', '45 no.jpg', '49 no.jpg', 'no 5.jpeg', 'No12.jpg', 'no 2.jpg', 'no 91.jpeg', '37 no.jpg', '46 no.jpg', 'no 96.jpg', 'no 97.jpg', 'no 98.jpg', 'no 923.jpg', 'no.jpg', 'no 95.jpg', 'no 99.jpg', 'no 94.jpg']
#
#
# ['/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/14 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/31 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/32 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/10 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/12 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/17 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/23 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/20 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/22 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/1 no.jpeg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/28 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/19 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/18 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/2 no.jpeg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/15 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/29 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/30 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/27 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/13 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/26 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/11 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/34 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/21 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/24 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/33 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/25 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/3 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/50 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/No14.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/39 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/N16.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/No11.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/5 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/6 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/42 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/no 100.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/N19.JPG', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/No21.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/No18.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/40 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/38 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/48 no.jpeg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/36 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/N2.JPG', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/No17.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/4 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/N15.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/N11.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/no 6.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/no 4.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/No22.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/44no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/N20.J ...
#
#
# ['No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', '
no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/6 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/42 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/no 100.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/N19.JPG', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/No21.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/No18.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/40 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/38 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/48 no.jpeg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/36 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/N2.JPG', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/No17.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/4 no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/N15.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/N11.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/no 6.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/no 4.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/No22.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/44no.jpg', '/content/drive/MyDrive/Colab Notebooks/Resources For Tumor /no/N20.J ...
#
#
# ['No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'No', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes', 'Yes']
#
#
# filepaths:  253    labels:  253

# %%
Files=pd.Series(filepaths, name='filepaths')
Label=pd.Series(labels, name='labels')
df=pd.concat([Files,Label], axis=1)
# df=pd.DataFrame(np.array(df).reshape(253,2), columns = ['filepaths', 'labels'])
# df.head()
df
# Out:
#                                              filepaths labels
# 0    /content/drive/MyDrive/Colab Notebooks/Resourc...     No
# 1    /content/drive/MyDrive/Colab Notebooks/Resourc...     No
# 2    /content/drive/MyDrive/Colab Notebooks/Resourc...     No
# 3    /content/drive/MyDrive/Colab Notebooks/Resourc...     No
# 4    /content/drive/MyDrive/Colab Notebooks/Resourc...     No
# ..                                                 ...    ...
# 248  /content/drive/MyDrive/Colab Notebooks/Resourc...    Yes
# 249  /content/drive/MyDrive/Colab Notebooks/Resourc...    Yes
# 250  /content/drive/MyDrive/Colab Notebooks/Resourc...    Yes
# 251  /content/drive/MyDrive/Colab Notebooks/Resourc...    Yes
# 252  /content/drive/MyDrive/Colab Notebooks/Resourc...    Yes
#
# [253 rows x 2 columns]

# %%
df['labels']=pd.get_dummies(df['labels'])

# %%
df
# Out:
#                                              filepaths  labels
# 0    /content/drive/MyDrive/Colab Notebooks/Resourc...       1
# 1    /content/drive/MyDrive/Colab Notebooks/Resourc...       1
# 2    /content/drive/MyDrive/Colab Notebooks/Resourc...       1
# 3    /content/drive/MyDrive/Colab Notebooks/Resourc...       1
# 4    /content/drive/MyDrive/Colab Notebooks/Resourc...       1
# ..                                                 ...     ...
# 248  /content/drive/MyDrive/Colab Notebooks/Resourc...       0
# 249  /content/drive/MyDrive/Colab Notebooks/Resourc...       0
# 250  /content/drive/MyDrive/Colab Notebooks/Resourc...       0
# 251  /content/drive/MyDrive/Colab Notebooks/Resourc...       0
# 252  /content/drive/MyDrive/Colab Notebooks/Resourc...       0
#
# [253 rows x 2 columns]

# %% [markdown]
# ### Visualize the image of brain tumour

# %%
plt.figure(figsize=(4,4))
for i in range(0,10):
    fig, ax = plt.subplots(figsize=(4,4))
    img = mpimg.imread(df['filepaths'][i])
    img_name = re.sub(r'^\D+','',df['filepaths'][i])
    ax.imshow(img)
    ax.set_title(img_name)

# %% [markdown]
# Since each image has different size, we need to resize them into same size

# %%
from PIL import Image
widths = []
heights = []
for idx, row in df.iterrows():
    path = row['filepaths']
#   print(path)
# brain_tumor_dataset/no/1 no.jpeg
# brain_tumor_dataset/no/10 no.jpg
# brain_tumor_dataset/no/11 no.jpg
# brain_tumor_dataset/no/12 no.jpg
# brain_tumor_dataset/no/13 no.jpg
# brain_tumor_dataset/no/14 no.jpg
    im = Image.open(path)
    
#     print(im)
# <PIL.JpegImagePlugin.JpegImageFile image mode=L size=630x630 at 0x1888E54F7C0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=173x201 at 0x1888E59BFA0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x1888E540340>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=275x183 at 0x1888D29BFA0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=300x168 at 0x1888E540C70>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=177x197 at 0x1888E5317F0>
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=232x217 at 0x1888E540C70>
#     print(im.size)
# (630, 630)
# (173, 201)
# (300, 168)
# (275, 183)
# (300, 168)
    width, height = im.size
    widths.append(width)
    heights.append(height)
avg_width = int(sum(widths) / len(widths))
avg_height = int(sum(heights) / len(heights))
print(avg_width, avg_height)
# Out:
# 354 386

# %% [markdown]
# The average width is 354 and the average height is 386.
# Making the width and height equal makes it simpler to do transformations later. So we’ll resize images to 300x300.

# %%
from keras.preprocessing.image import load_img

# Image Resize Function
def load_resize_color_image(path):
    # load image and resize to 300x300
    image = load_img(path,target_size=(300,300))
    return image

# %%
image_list =[]
cancer_list =[]
from keras.preprocessing.image import img_to_array
for idx, row in df.iterrows():
    path = row['filepaths']
    cancer = row['labels']
#   print(path)
#   print(cancer)
# brain_tumor_dataset/no/1 no.jpeg
# No
# brain_tumor_dataset/no/10 no.jpg
# No
    image = load_resize_color_image(path)
    # turn image to array
    image_array = img_to_array(image)   
    image_list.append(image_array)
    cancer_list.append(cancer)

# %%
# print(image_list[0:5])

# %%
print(cancer_list[0:5])
# Out:
# [1, 1, 1, 1, 1]

# %% [markdown]
# ### Shuffle the image and label

# %%
from sklearn.utils import shuffle
image_list, cancer_list = shuffle(image_list, cancer_list)

# %% [markdown]
# ### Define our X, y for train-test-split

# %%
X_data = np.array(image_list)
y_data = np.array(cancer_list)

# %%
print(X_data.shape)
print(y_data.shape)
# Out:
# (253, 300, 300, 3)
# (253,)

# %% [markdown]
# ### Split into training set and testing set

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_data, y_data, train_size=0.8, random_state=0)

# %%
print(X_train.shape)
print(y_train.shape)
# Out:
# (202, 300, 300, 3)
# (202,)

# %%
X_train = X_train/255
X_test = X_test/255

# %%
print(X_test.shape)
print(y_test.shape)
# Out:
# (51, 300, 300, 3)
# (51,)

# %% [markdown]
# ### Building CNN Model Architecture

# %%
epochs = 10
batch_size = 10
input_shape = (300,300,3)

# %%
model = Sequential()
model.add(Conv2D(64, kernel_size=(3, 3),activation='relu',input_shape=input_shape))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Conv2D(64, kernel_size=(3, 3), activation='relu'))
model.add(MaxPooling2D(pool_size=(2, 2)))
model.add(Flatten())
# ANN structure
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dropout(0.5))
model.add(Dense(1, activation='sigmoid'))

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d (Conv2D)              (None, 298, 298, 64)      1792
# _________________________________________________________________
# max_pooling2d (MaxPooling2D) (None, 149, 149, 64)      0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 147, 147, 64)      36928
# _________________________________________________________________
# max_pooling2d_1 (MaxPooling2 (None, 73, 73, 64)        0
# _________________________________________________________________
# conv2d_2 (Conv2D)            (None, 71, 71, 64)        36928
# _________________________________________________________________
# max_pooling2d_2 (MaxPooling2 (None, 35, 35, 64)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 78400)             0
# _________________________________________________________________
# dense (Dense)                (None, 128)               10035328
# _________________________________________________________________
# dense_1 (Dense)              (None, 64)                8256
# _________________________________________________________________
# dropout (Dropout)            (None, 64)                0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 65
# =================================================================
# Total params: 10,119,297
# Trainable params: 10,119,297
# Non-trainable params: 0
# _________________________________________________________________

# %%
#   define compile to minimize categorical loss, use ada delta optimized, and optimize to maximizing accuracy
model.compile(loss="binary_crossentropy",
              optimizer='Adam',
              metrics=['accuracy'])

#   Train the model and test/validate the mode with the test data after each cycle (epoch) through the training data
#   Return history of loss and accuracy for each epoch
hist = model.fit(X_train, y_train,
          batch_size=batch_size,
          epochs=epochs,
          verbose=1,
          validation_data=(X_test, y_test))
# Out:
# Epoch 1/10
# 21/21 [==============================] - 51s 2s/step - loss: 0.6719 - accuracy: 0.6337 - val_loss: 0.4292 - val_accuracy: 0.8039
# Epoch 2/10
# 21/21 [==============================] - 50s 2s/step - loss: 0.5777 - accuracy: 0.7178 - val_loss: 0.4774 - val_accuracy: 0.8235
# Epoch 3/10
# 21/21 [==============================] - 50s 2s/step - loss: 0.4733 - accuracy: 0.8168 - val_loss: 0.4525 - val_accuracy: 0.8235
# Epoch 4/10
# 21/21 [==============================] - 50s 2s/step - loss: 0.3689 - accuracy: 0.8465 - val_loss: 0.6248 - val_accuracy: 0.8235
# Epoch 5/10
# 21/21 [==============================] - 50s 2s/step - loss: 0.2141 - accuracy: 0.9257 - val_loss: 0.6279 - val_accuracy: 0.8824
# Epoch 6/10
# 21/21 [==============================] - 50s 2s/step - loss: 0.2173 - accuracy: 0.9307 - val_loss: 0.6862 - val_accuracy: 0.8431
# Epoch 7/10
# 21/21 [==============================] - 50s 2s/step - loss: 0.0978 - accuracy: 0.9604 - val_loss: 0.8602 - val_accuracy: 0.8431
# Epoch 8/10
# 21/21 [==============================] - 50s 2s/step - loss: 0.1432 - accuracy: 0.9554 - val_loss: 0.7568 - val_accuracy: 0.8627
# Epoch 9/10
# 21/21 [==============================] - 49s 2s/step - loss: 0.0990 - accuracy: 0.9554 - val_loss: 0.8341 - val_accuracy: 0.8824
# Epoch 10/10
# 21/21 [==============================] - 50s 2s/step - loss: 0.0877 - accuracy: 0.9703 - val_loss: 0.7982 - val_accuracy: 0.8235

# %%
score = model.evaluate(X_test, y_test, verbose=0)
print('Test loss:', score[0])
print('Test accuracy:', score[1])

#   Plot data to see relationships in training and validation data
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
epoch_list = list(range(1, len(hist.history['accuracy']) + 1))  # values for x axis [1, 2, ..., # of epochs]
plt.plot(epoch_list, hist.history['accuracy'], epoch_list, hist.history['val_accuracy'])
plt.legend(('Training Accuracy', 'Validation Accuracy'))
plt.show()
# Out:
# Test loss: 0.79815673828125
# Test accuracy: 0.8235294222831726

# %%
image = Image.open('/content/drive/MyDrive/brain_tumor/yes/Y100.JPG')
im_array = np.asarray(image)
plt.imshow(im_array)
plt.show()

# %%
result = brain_tumor_model.predict(test_image)
result=int(result[0,0])
if result == 1:
  prediction = 'NO'
else:
  prediction = 'YES'
print(prediction)
# Out:
# YES
